# %%
import sqlite3

conn = sqlite3.connect("customer_segmentation.db")
cursor = conn.cursor()

try:
    cursor.execute(
        "ALTER TABLE clustering_history ADD COLUMN davies_score REAL"
    )
except:
    pass

try:
    cursor.execute(
        "ALTER TABLE clustering_history ADD COLUMN calinski_score REAL"
    )
except:
    pass

try:
    cursor.execute(
        "ALTER TABLE clustering_history ADD COLUMN cluster_summary TEXT"
    )
except:
        pass

conn.commit()
conn.close()

print("Database Updated Successfully")
# Out:
# Database Updated Successfully
